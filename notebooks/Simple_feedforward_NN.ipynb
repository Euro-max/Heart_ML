# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import layers
#  Scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Get the number of features after preprocessing
num_features = X_train_scaled.shape[1]

#  Define the Keras model architecture
# I'll build a simple network with two hidden layers
model = keras.Sequential([
    # Input layer with a dense layer. The input_shape is required for the first layer.
    layers.Dense(64, activation='relu', input_shape=(num_features,)),

    # A second dense hidden layer
    layers.Dense(32, activation='relu'),
    #layers.Dense(16, activation='relu'),
    # The output layer. It has 5 neurons for our 5 classes and uses Softmax activation
    # to output a probability distribution over the classes.
    layers.Dense(5, activation='softmax')
])


#  Compile the model

model.compile(
    optimizer='adam', # The Adam optimizer is a great default choice
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'] # Track accuracy during training
)

print("\nModel Summary:")
model.summary()

#  Train the model
# The fit() method trains the network
print("\nTraining the neural network...")
history = model.fit(
    X_train_scaled,
    y_train,
    epochs=60,       # Number of times to iterate over the entire dataset
    batch_size=32,   # Number of samples per gradient update
    validation_split=0.2, # Hold out a portion of the training data for validation
    verbose=1
)


#  Evaluate the model on the test data
print("\nEvaluating the model on the test set...")
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Model Summary:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_74 (Dense)                │ (None, 64)             │         1,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_76 (Dense)                │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,909 (15.27 KB)
#  Trainable params: 3,909 (15.27 KB)
#  Non-trainable params: 0 (0.00 B)
# Training the neural network...
# Epoch 1/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.2453 - loss: 1.6523 - val_accuracy: 0.5833 - val_loss: 1.3262
# Epoch 2/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4712 - loss: 1.4358 - val_accuracy: 0.6458 - val_loss: 1.1466
# Epoch 3/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5205 - loss: 1.2922 - val_accuracy: 0.6667 - val_loss: 1.0209
# Epoch 4/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4784 - loss: 1.2376 - val_accuracy: 0.7083 - val_loss: 0.9450
# Epoch 5/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5618 - loss: 1.1194 - val_accuracy: 0.7292 - val_loss: 0.8937
# Epoch 6/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5447 - loss: 1.0832 - val_accuracy: 0.7292 - val_loss: 0.8677
# Epoch 7/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5593 - loss: 1.0777 - val_accuracy: 0.6458 - val_loss: 0.8567
# Epoch 8/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5469 - loss: 1.0502 - val_accuracy: 0.6667 - val_loss: 0.8499
# Epoch 9/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6387 - loss: 0.9251 - val_accuracy: 0.6667 - val_loss: 0.8472
# Epoch 10/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6498 - loss: 0.9408 - val_accuracy: 0.6875 - val_loss: 0.8496
# Epoch 11/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6432 - loss: 0.9381 - val_accuracy: 0.6875 - val_loss: 0.8494
# Epoch 12/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6921 - loss: 0.8463 - val_accuracy: 0.6875 - val_loss: 0.8474
# Epoch 13/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6927 - loss: 0.8511 - val_accuracy: 0.6667 - val_loss: 0.8448
# Epoch 14/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6727 - loss: 0.8148 - val_accuracy: 0.6458 - val_loss: 0.8435
# Epoch 15/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7106 - loss: 0.7799 - val_accuracy: 0.6875 - val_loss: 0.8429
# Epoch 16/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7016 - loss: 0.8019 - val_accuracy: 0.6875 - val_loss: 0.8404
# Epoch 17/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.
60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8972 - loss: 0.3926 - val_accuracy: 0.6250 - val_loss: 0.9745
# Epoch 49/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8981 - loss: 0.3834 - val_accuracy: 0.6250 - val_loss: 0.9906
# Epoch 50/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8999 - loss: 0.3663 - val_accuracy: 0.6250 - val_loss: 0.9973
# Epoch 51/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8918 - loss: 0.3439 - val_accuracy: 0.6250 - val_loss: 1.0003
# Epoch 52/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9063 - loss: 0.3670 - val_accuracy: 0.6250 - val_loss: 1.0095
# Epoch 53/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9191 - loss: 0.3302 - val_accuracy: 0.6250 - val_loss: 1.0128
# Epoch 54/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9240 - loss: 0.3195 - val_accuracy: 0.6250 - val_loss: 1.0254
# Epoch 55/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9111 - loss: 0.3416 - val_accuracy: 0.6250 - val_loss: 1.0377
# Epoch 56/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9237 - loss: 0.3060 - val_accuracy: 0.6250 - val_loss: 1.0483
# Epoch 57/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9375 - loss: 0.2975 - val_accuracy: 0.6250 - val_loss: 1.0575
# Epoch 58/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9070 - loss: 0.3112 - val_accuracy: 0.6250 - val_loss: 1.0694
# Epoch 59/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9359 - loss: 0.2919 - val_accuracy: 0.6250 - val_loss: 1.0695
# Epoch 60/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9463 - loss: 0.3103 - val_accuracy: 0.6250 - val_loss: 1.0766
#
# Evaluating the model on the test set...
#
# Test Loss: 1.2017
# Test Accuracy: 0.6167

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from sklearn.preprocessing import StandardScaler

#  Scale the data (assuming X_train and X_test are already defined and preprocessed)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Get the number of features after preprocessing
num_features = X_train_scaled.shape[1]
n_classes = len(np.unique(y_train)) # Get the number of unique classes

inputs = keras.Input(shape=(num_features,))

# A few dense layers
x = layers.Dense(64, activation='relu')(inputs)
x = layers.Dense(32, activation='relu')(x)


y = x


x = layers.Dense(16, activation='relu')(x)


y = layers.Dense(16, activation='relu')(y) # Add a dense layer to y to match shape of x
x = layers.add([x, y])


outputs = layers.Dense(n_classes, activation='softmax')(x)


model = Model(inputs=inputs, outputs=outputs)



model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("\nModel Summary:")
model.summary()


print("\nTraining the functional model...")
history = model.fit(
    X_train_scaled,
    y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)


# Step 5: Evaluate the model on the test data (same as with Sequential)
print("\nEvaluating the model on the test set...")
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)

print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Model Summary:
# Model: "functional_15"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_16      │ (None, 25)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_52 (Dense)    │ (None, 64)        │      1,664 │ input_layer_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_53 (Dense)    │ (None, 32)        │      2,080 │ dense_52[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_54 (Dense)    │ (None, 16)        │        528 │ dense_53[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_55 (Dense)    │ (None, 16)        │        528 │ dense_53[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16)        │          0 │ dense_54[0][0],   │
# │                     │                   │            │ dense_55[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_56 (Dense)    │ (None, 5)         │         85 │ add_1[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,885 (19.08 KB)
#  Trainable params: 4,885 (19.08 KB)
#  Non-trainable params: 0 (0.00 B)
# Training the functional model...
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.3797 - loss: 1.5944 - val_accuracy: 0.5833 - val_loss: 1.3512
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8967 - loss: 0.3498 - val_accuracy: 0.6458 - val_loss: 1.0437
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9273 - loss: 0.2889 - val_accuracy: 0.6458 - val_loss: 1.0482
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9203 - loss: 0.3271 - val_accuracy: 0.6458 - val_loss: 1.0433
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9189 - loss: 0.2965 - val_accuracy: 0.6458 - val_loss: 1.0599
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9206 - loss: 0.2981 - val_accuracy: 0.6458 - val_loss: 1.0727
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9269 - loss: 0.2775 - val_accuracy: 0.6458 - val_loss: 1.0831
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9150 - loss: 0.2778 - val_accuracy: 0.6667 - val_loss: 1.0951
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9558 - loss: 0.2078 - val_accuracy: 0.6667 - val_loss: 1.1038
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9061 - loss: 0.2684 - val_accuracy: 0.6667 - val_loss: 1.1183
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9451 - loss: 0.2164 - val_accuracy: 0.6667 - val_loss: 1.1253
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9252 - loss: 0.2237 - val_accuracy: 0.6458 - val_loss: 1.1463
#
# Evaluating the model on the test set...
#
# Test Loss: 1.1698
# Test Accuracy: 0.5833

# %%
train_data
# Out:
#      age  trestbps   chol    thalch   oldpeak   ca  num  sex_Female  sex_Male  \
# 6     62     140.0  268.0  5.081404  1.526056  2.0    3        True     False
# 185   63     140.0  195.0  5.192957  0.000000  2.0    0        True     False
# 187   66     160.0  246.0  4.795791  0.000000  3.0    2       False      True
# 147   41     112.0  250.0  5.192957  0.000000  0.0    0       False      True
# 30    69     140.0  239.0  5.023881  1.029619  2.0    0        True     False
# ..   ...       ...    ...       ...       ...  ...  ...         ...       ...
# 190   50     129.0  196.0  5.099866  0.000000  0.0    0       False      True
# 71    67     125.0  254.0  5.099866  0.182322  2.0    3       False      True
# 107   57     128.0  229.0  5.017280  0.336472  1.0    1       False      True
# 274   59     134.0  204.0  5.093750  0.587787  2.0    1       False      True
# 103   71     110.0  265.0  4.875197  0.000000  1.0    0        True     False
#
#      cp_asymptomatic  ...  restecg_normal  restecg_st-t abnormality  \
# 6               True  ...           False                     False
# 185            False  ...            True                     False
# 187            False  ...            True                     False
# 147            False  ...            True                     False
# 30             False  ...            True                     False
# ..               ...  ...             ...                       ...
# 190            False  ...            True                     False
# 71              True  ...            True                     False
# 107            False  ...           False                     False
# 274            False  ...            True                     False
# 103            False  ...           False                     False
#
#      exang_False  exang_True  slope_downsloping  slope_flat  slope_upsloping  \
# 6           True       False               True       False            False
# 185         True       False              False       False             True
# 187        False        True              False        True            False
# 147         True       False              False       False             True
# 30          True       False              False       False             True
# ..           ...         ...                ...         ...              ...
# 190         True       False              False       False             True
# 71          True       False              False        True            False
# 107         True       False              False        True            False
# 274         True       False              False       False             True
# 103         True       False              False       False             True
#
#      thal_fixed defect  thal_normal  thal_reversable defect
# 6                False         True                   False
# 185              False         True                   False
# 187               True        False                   False
# 147              False         True                   False
# 30               False         True                   False
# ..                 ...          ...                     ...
# 190              False         True                   False
# 71               False        False                    True
# 107              False        False                    True
# 274              False         True                   False
# 103              False         True                   False
#
# [239 rows x 26 columns]
